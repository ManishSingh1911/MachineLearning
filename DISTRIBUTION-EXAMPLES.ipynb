# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.mixture import GaussianMixture
x= np.random.multivariate_normal([175,16],[[4,3.5],[3.5,4]],1000)
plt.scatter(x[:,0],x[:,1])
